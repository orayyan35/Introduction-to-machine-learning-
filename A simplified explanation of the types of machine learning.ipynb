# %% [markdown]
# ### TYPE ML :-

# %% [markdown]
# ![1_31iqrQyCqIuuGPLUK_BjMQ.png](attachment:1_31iqrQyCqIuuGPLUK_BjMQ.png)

# %% [markdown]
# ## 1-supervision (u have input and output )
#         a- regression (التوقع)
#         b- classification (التقسيم)
#         c- NN (الشبكه العصبيه)
#         D- SVM (النظام الدعم الالي )

# %% [markdown]
# A simple translation for your explanation:
#
# This type of explanation is about having inputs and outputs, and you want to train a model based on this information so that it can predict future information based on the data it has been trained on. That's why the data needs to be clean and filtered correctly, without any errors, to ensure that the values are logical.
#
# (In theory, there might be logical data, but realistically, it's impossible to have perfectly clean and filtered data without any margin of error)

# %% [markdown]
# -----

# %% [markdown]
# supervision:
#
# #### A-regression (التوقع):
#
#     it is  idea u have interconnected data  and I want to know         the values of new data
#
# --------------
# regression Applications :-
#
# a- Weather condition
#
# b- House prices

# %% [markdown]
# --------
# B- classification:
#
#     u have interconnected data and  I want to divide
#     it into similar groups

# %% [markdown]
# ![Regression_vs_Classification.avif](attachment:Regression_vs_Classification.avif)

# %% [markdown]
# -------------

# %% [markdown]
# ## 2-unspervision :-
#      A- clustering

# %% [markdown]
# A- clustring :
#
#       u have data but u dont know any information for data and u         need divid for Similar group

# %% [markdown]
# Consider that you have a traffic camera, and you want this camera to capture everything that comes in front of it and be able to recognize everything it captures without you manually telling it what things are. It learns and adapts without you inputting specific data for training.
#
#
# ----
# And another thing I have to differentiate between
#
#      clustring (unknow output)
#      and
#      classification (know output)

# %% [markdown]
# ![6466f65437077_classification_and_clustering.jpg](attachment:6466f65437077_classification_and_clustering.jpg)

# %% [markdown]
#      time : 2:00 AM
#      date : 11/9/2023
#      by omar baker
